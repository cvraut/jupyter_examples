# %% [markdown]
# # whecho tutorial

# %% [markdown]
# Recently, Wendy and I came up with a tool that I thought would be useful to keep track of long-running jobs. We titled it [whecho (webhooks echo)](https://github.com/cvraut/whecho).
#
# ![WHECHO_LOGO.png](attachment:b51f5280-af8a-4c72-ae77-fcbbf22d3d3b.png)
#
# The goal is that it should work like linux echo except instead of printing the echo'ed string to stdout it prints it to the webhook that the user sets.

# %% [markdown]
# # installation

# %% [markdown]
# whecho is already setup on [speliotes-jupyterhub](https://speliotes-jupyter.med.umich.edu/)
#
# If you want to set it up yourself, in a conda environment u must run `pip install whecho`. (Note: this will only install whecho in the current conda environment and will have to be repeated if you use multiple conda environments frequently). It is unadvised to install whecho globally as it is written in python and dependencies are resolved to be environment specific. Refer to [Lishi's earlier message for an example of a conda environment that supports R and python with whecho](https://discord.com/channels/1073360774615011348/1157410255181987851/1202500468023238726).

# %% [markdown]
# # First time setup

# %% [markdown]
# If you have never used whecho, it is advised to run `whecho --init` **in a terminal or bash shell** and set the default url to channel that you are subscribed to.
# ![image.png](attachment:c1cfc2ff-079c-4dae-ac92-b032e4963ee1.png)
# ![image.png](attachment:0ca1dc43-7e02-4104-b46b-e6b7ad51c299.png)
#
#
# To start with, feel free to use [the webhook created in our servers channel](https://discord.com/channels/1073360774615011348/1157410255181987851/1201585159368089641) (access restricted for obvious reasons):
# ![image.png](attachment:3c0eb732-c890-4135-a43b-7241d1e31e47.png)
#
# But for prolonged or advanced usage I would recommend setting up a private server and creating a private webhook url for a channel in that server.

# %% [markdown]
# # using whecho

# %%
# bash
! sleep 5 
! whecho done sleeping for 5 sec!

# %% [markdown]
# ![image.png](attachment:3c5b51d3-8a2b-4ef5-994e-15569462f8d3.png)

# %%
# python (api under construction, but feel free to use subprocess or os modules for now)
import os
from time import sleep
sleep(5)
os.system("whecho done sleeping for 5 sec in 🐍!")
# Out:
# 0

# %% [markdown]
# ![image.png](attachment:dac4040e-f10d-4183-b6c0-d387bfdaeedf.png)

# %% [markdown]
# # More details and options

# %%
! whecho --help
# Out:
# usage: whecho [-h] [--version] [-m MSG] [--init] [-u URL] [-d] [MSG ...]
#
# Linux echo with webhooks! ⚓
#
# positional arguments:
#   MSG                The message to echo.
#
# options:
#   -h, --help         show this help message and exit
#   --version          Prints the version of whecho and exits.
#   -m MSG, --msg MSG  The message to echo (same as 1st positional argument).
#   --init             Initializes whecho.
#   -u URL, --url URL  The webhook URL to send the message to.
#   -d, --debug        Whether to print debugging information.
