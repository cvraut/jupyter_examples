# %% [markdown]
# # R Example

# %% [markdown]
# This notebook is just an example of R code running in a jupyter environment.

# %%
#This code is AI-generated. Review and use carefully. Visit our FAQ for more information.

# Load the required packages
library(ggplot2)

# Generate some random data
set.seed(123)  # for reproducibility
data <- data.frame(
  x = rnorm(100),  # 100 random numbers from a standard normal distribution
  y = rnorm(100)   # another 100 random numbers
)

# Create a scatter plot of y vs. x
p <- ggplot(data, aes(x=x, y=y)) +
  geom_point() +
  ggtitle("Scatter plot of random data")

# Print the plot
print(p)
# Out:
# plot without title
